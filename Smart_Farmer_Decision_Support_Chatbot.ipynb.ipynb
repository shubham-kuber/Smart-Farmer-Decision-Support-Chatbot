# %% [markdown]
# # PROJECT INTRO

# %%
print("="*70)
print("🌾 SMART FARMER DECISION SUPPORT CHATBOT 🌾")
print("Cultivation + Selling + Market Intelligence System")
print("Designed for real farmer problems & value-based decisions")
print("="*70)
# Out:
# ...
# 🌾 SMART FARMER DECISION SUPPORT CHATBOT 🌾
# Cultivation + Selling + Market Intelligence System
# Designed for real farmer problems & value-based decisions
# ...

# %% [markdown]
# # COMPLETE CROP DATABASE (FINAL)

# %%
crop_data = {

    # ---------------- VEGETABLES ----------------
    "टोमॅटो": {
        "type": "Vegetable",
        "cultivation": {
            "जमीन": "मध्यम, चांगला निचरा असलेली",
            "हवामान": "20–30°C",
            "पाणी": "जास्त पाणी दिल्यास फुलगळ होते",
            "खत": "जास्त युरिया = पाने वाढतात, फळधारणा कमी",
            "महत्वाचे": "पाणी साचू देऊ नका"
        },
        "selling": {
            "low": "गावातील व्यापारी / आठवडी बाजार",
            "medium": "शहर मार्केट",
            "high": "मोठी बाहेरील बाजारपेठ",
            "value": "ग्रेडिंग + पॅकिंग = 2x–3x दर शक्य"
        }
    },

    "कांदा": {
        "type": "Vegetable",
        "cultivation": {
            "जमीन": "काळी / लाल भुसभुशीत",
            "हवामान": "थंड व कोरडं",
            "पाणी": "अति पाणी दिल्यास कांदे कुजतात",
            "खत": "संतुलित खत",
            "महत्वाचे": "काढणीपूर्वी पाणी बंद"
        },
        "selling": {
            "low": "स्थानिक व्यापारी",
            "medium": "APMC मार्केट",
            "high": "बाहेरची मोठी market",
            "value": "साठवणूक केल्यास दर वाढतो"
        }
    },

    "बटाटा": {
        "type": "Vegetable",
        "cultivation": {
            "जमीन": "सैल व भुसभुशीत",
            "हवामान": "थंड",
            "पाणी": "मर्यादित",
            "खत": "पोटॅश आवश्यक",
            "महत्वाचे": "उशिरा काढणी टाळा"
        },
        "selling": {
            "low": "स्थानिक बाजार",
            "medium": "कोल्ड स्टोरेज",
            "high": "प्रोसेसिंग उद्योग",
            "value": "कोल्ड स्टोरेज = जास्त नफा"
        }
    },

    # ---------------- FRUITS ----------------
    "केळी": {
        "type": "Fruit",
        "cultivation": {
            "जमीन": "सेंद्रिय पदार्थ भरपूर",
            "हवामान": "उष्ण व दमट",
            "पाणी": "नियमित पण नियंत्रित",
            "खत": "पोटॅश जास्त आवश्यक",
            "महत्वाचे": "वाऱ्यापासून संरक्षण"
        },
        "selling": {
            "low": "जवळचा व्यापारी",
            "medium": "शहर फळ मार्केट",
            "high": "बाहेरील राज्य मार्केट",
            "value": "घोस पॅकिंग = premium दर"
        }
    },

    "द्राक्ष": {
        "type": "Fruit",
        "cultivation": {
            "जमीन": "चांगला निचरा असलेली",
            "हवामान": "कोरडं",
            "पाणी": "नियंत्रित",
            "खत": "कॅल्शियम महत्त्वाचं",
            "महत्वाचे": "अति पाणी टाळा"
        },
        "selling": {
            "low": "स्थानिक बाजार",
            "medium": "शहर मार्केट",
            "high": "Export channel",
            "value": "ग्रेडिंग = export quality"
        }
    },

    # ---------------- POMEGRANATE ----------------
    "डाळिंब": {
        "type": "Fruit",
        "cultivation": {
            "Rest Management": "9–12 महिने पाणी बंद, रेतीचा वापर",
            "Stress Control": "1–2 हलक्या फवारण्या",
            "Water Activation": "जानेवारीत चाटणी करून पाणी सुरू",
            "Mulching": "ऊस पाचट / नारळ पाला",
            "Pollination": "मधमाशी आकर्षण",
            "Organic Inputs": "गौमूत्र, शेणखत, bacteria culture",
            "Fruit Quality": "फांद्यांची बांधणी व नियंत्रित पाणी"
        },
        "selling": {
            "low": "स्थानिक बाजार",
            "medium": "शहर फळ मार्केट",
            "high": "Export / बाहेरील राज्य",
            "value": "Box packing + grading = premium दर"
        }
    }
}

# %% [markdown]
# # CULTIVATION MODULE

# %%
def cultivation_module(crop):
    print("\n🌱 लागवड मार्गदर्शन:")
    data = crop_data[crop]["cultivation"]

    for k, v in data.items():
        print(f"- {k} : {v}")

# %% [markdown]
# # SELLING & MARKET DECISION MODULE

# %%
def selling_module(crop):
    print("\n🧺 विक्री निर्णय सहाय्य:")

    qty = int(input("तुमच्याकडे किती किलो उत्पादन आहे? "))

    sell = crop_data[crop]["selling"]

    if qty < 100:
        market = sell["low"]
    elif qty < 500:
        market = sell["medium"]
    else:
        market = sell["high"]

    print("📍 सुचवलेली बाजारपेठ:", market)

    value = input("ग्रेडिंग / पॅकिंग केलं आहे का? (हो/नाही): ")

    if value == "हो":
        print("💡 Value Insight:", sell["value"])
    else:
        print("ℹ️ ग्रेडिंग व पॅकिंग केल्यास अधिक दर मिळू शकतो")

# %% [markdown]
# # MAIN CHATBOT ENGINE (FINAL)

# %%
while True:
    print("\nउपलब्ध पिके:")
    for crop in crop_data:
        print("-", crop, f"({crop_data[crop]['type']})")

    choice = input("\nपीक निवडा (exit लिहा बंद करण्यासाठी): ")

    if choice == "exit":
        print("\n🙏 धन्यवाद! स्मार्ट शेतीसाठी शुभेच्छा 🌾")
        break

    if choice not in crop_data:
        print("या पिकाची माहिती उपलब्ध नाही")
        continue

    cultivation_module(choice)
    selling_module(choice)
# Out:
# उपलब्ध पिके:
# - टोमॅटो (Vegetable)
# - कांदा (Vegetable)
# - बटाटा (Vegetable)
# - केळी (Fruit)
# - द्राक्ष (Fruit)
# - डाळिंब (Fruit)
# पीक निवडा (exit लिहा बंद करण्यासाठी):  डाळिंब
# 🌱 लागवड मार्गदर्शन:
# - Rest Management : 9–12 महिने पाणी बंद, रेतीचा वापर
# - Stress Control : 1–2 हलक्या फवारण्या
# - Water Activation : जानेवारीत चाटणी करून पाणी सुरू
# - Mulching : ऊस पाचट / नारळ पाला
# - Pollination : मधमाशी आकर्षण
# - Organic Inputs : गौमूत्र, शेणखत, bacteria culture
# - Fruit Quality : फांद्यांची बांधणी व नियंत्रित पाणी
#
# 🧺 विक्री निर्णय सहाय्य:
